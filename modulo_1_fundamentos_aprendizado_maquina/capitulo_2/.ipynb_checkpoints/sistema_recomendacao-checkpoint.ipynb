# %%
#código utilizado como exemplo de sistema de recomendação para a disciplina FAM
#datasets utilizados podem ser encontrado também em https://grouplens.org/datasets/movielens/

# %%
import pandas as pd #biblioteca utilizada para lidar com os dataframes

# %%
#lendo os arquivos 
df_movies=pd.read_csv('movies.csv')
df_ratings=pd.read_csv('ratings.csv')

# %%
df_ratings.head() #unixtimestamp 01/01/1970
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_movies.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
#analisando o dataset
#recuperando qual é o nome do filme com id = 50
print(df_movies[df_movies['movieId']==50])
# Out:
#     movieId                       title                  genres
# 46       50  Usual Suspects, The (1995)  Crime|Mystery|Thriller

# %%
#agrupando os dataframe para ter a junção de cada usuário e filme que viu
movie_rating=pd.merge(df_movies,df_ratings, on='movieId') #combina os dataframe por meio do id do filme

# %%
movie_rating.head()
# Out:
#    movieId             title  ... rating   timestamp
# 0        1  Toy Story (1995)  ...    4.0   964982703
# 1        1  Toy Story (1995)  ...    4.0   847434962
# 2        1  Toy Story (1995)  ...    4.5  1106635946
# 3        1  Toy Story (1995)  ...    2.5  1510577970
# 4        1  Toy Story (1995)  ...    4.5  1305696483
#
# [5 rows x 6 columns]

# %%
#analisando os dados
import matplotlib.pyplot as plt  #biblioteca utilizada para plotar gráficos ao estilo matlab
import seaborn as sns #biblioteca utilizada para plotar gráficos mais detalhados

# %%
#encontrando o valor médio das notas atribuídas para cada filme
movie_rating.groupby('title')['rating'].mean().sort_values(ascending=False).head() # agrupa o dataframe movie_rating pela coluna titulo
#encontra a média das notas de cada filme e ordena a lista dos valores
# Out:
# title
# Karlson Returns (1970)                           5.0
# Winter in Prostokvashino (1984)                  5.0
# My Love (2006)                                   5.0
# Sorority House Massacre II (1990)                5.0
# Winnie the Pooh and the Day of Concern (1972)    5.0
# Name: rating, dtype: float64

# %%
#conta a quantidade de notas (rating) que cada filme recebeu
movie_rating.groupby('title')['rating'].count().sort_values(ascending=False).head()#agrupa o dataframe movie_rating pela coluna titulo
#soma a quantidade de notas que cada filme recebeu e ordena a lista
# Out:
# title
# Forrest Gump (1994)                 329
# Shawshank Redemption, The (1994)    317
# Pulp Fiction (1994)                 307
# Silence of the Lambs, The (1991)    279
# Matrix, The (1999)                  278
# Name: rating, dtype: int64

# %%
#cria o dataframe que vai conter o nome de cada filme e a media das notas recebidas 
ratings = pd.DataFrame(movie_rating.groupby('title')['rating'].mean())
ratings.sort_values(by='rating',ascending=False).head()
# Out:
#                                      rating
# title
# Gena the Crocodile (1969)               5.0
# True Stories (1986)                     5.0
# Cosmic Scrat-tastrophe (2015)           5.0
# Love and Pigeons (1985)                 5.0
# Red Sorghum (Hong gao liang) (1987)     5.0

# %%
#adiciona a coluna que contem a quantidade de notas que cada um dos filmes recebeu
ratings['num de avaliacoes']=pd.DataFrame(movie_rating.groupby('title')['rating'].count())
ratings.sort_values(by='num de avaliacoes',ascending=False).head()
# Out:
#                                     rating  num de avaliacoes
# title
# Forrest Gump (1994)               4.164134                329
# Shawshank Redemption, The (1994)  4.429022                317
# Pulp Fiction (1994)               4.197068                307
# Silence of the Lambs, The (1991)  4.161290                279
# Matrix, The (1999)                4.192446                278

# %%
ratings.sort_values(by='rating',ascending=False).head()
# Out:
#                                      rating  num de avaliacoes
# title
# Gena the Crocodile (1969)               5.0                  1
# True Stories (1986)                     5.0                  1
# Cosmic Scrat-tastrophe (2015)           5.0                  1
# Love and Pigeons (1985)                 5.0                  1
# Red Sorghum (Hong gao liang) (1987)     5.0                  1

# %%
#analisando os dados
ratings.boxplot(column='rating');

# %%
#analisando os dados
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70); #plota o histograma para a média das notas recebidas

# %%
#construção da matriz que relaciona cada usuário à nota (rating) que ele atribuiu a cada filme
movie_rating_matrix = movie_rating.pivot_table(index='userId',columns='title',values='rating')
movie_rating_matrix.tail()
# Out:
# title   '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# userId              ...
# 606            NaN  ...                                        NaN
# 607            NaN  ...                                        NaN
# 608            NaN  ...                                        NaN
# 609            NaN  ...                                        NaN
# 610            4.0  ...                                        NaN
#
# [5 rows x 9719 columns]

# %%
#constroi a matriz de correlação entre cada um dos filmes 
movie_corr_matrix=movie_rating_matrix.corr()
movie_corr_matrix.head()
# Out:
# title                                    '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# title                                                ...
# '71 (2014)                                      NaN  ...                                        NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN  ...                                        NaN
# 'Round Midnight (1986)                          NaN  ...                                        NaN
# 'Salem's Lot (2004)                             NaN  ...                                        NaN
# 'Til There Was You (1997)                       NaN  ...                                        NaN
#
# [5 rows x 9719 columns]

# %%
#refina a marix de correlação 
movie_corr_matrix=movie_rating_matrix.corr(method='pearson', min_periods=50)# utiliza o método de pearson para gerar a correlação 
#apenas considera as correlações entre filmes que tiveram mais de 50 avaliações
movie_corr_matrix.head()
# Out:
# title                                    '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# title                                                ...
# '71 (2014)                                      NaN  ...                                        NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN  ...                                        NaN
# 'Round Midnight (1986)                          NaN  ...                                        NaN
# 'Salem's Lot (2004)                             NaN  ...                                        NaN
# 'Til There Was You (1997)                       NaN  ...                                        NaN
#
# [5 rows x 9719 columns]

# %%
movie_corr_matrix.head(20)
# Out:
# title                                        '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# title                                                    ...
# '71 (2014)                                          NaN  ...                                        NaN
# 'Hellboy': The Seeds of Creation (2004)             NaN  ...                                        NaN
# 'Round Midnight (1986)                              NaN  ...                                        NaN
# 'Salem's Lot (2004)                                 NaN  ...                                        NaN
# 'Til There Was You (1997)                           NaN  ...                                        NaN
# 'Tis the Season for Love (2015)                     NaN  ...                                        NaN
# 'burbs, The (1989)                                  NaN  ...                                        NaN
# 'night Mother (1986)                                NaN  ...                                        NaN
# (500) Days of Summer (2009)                         NaN  ...                                        NaN
# *batteries not included (1987)                      NaN  ...                                        NaN
# ...All the Marbles (1981)                           NaN  ...                                        NaN
# ...And Justice for All (1979)                       NaN  ...                                        NaN
# 00 Schneider - Jagd auf Nihil Baxter (1994)         NaN  ...                                        NaN
# 1-900 (06) (1994)                                   NaN  ...                                        NaN
# 10 (1979)                                           NaN  ...                                        NaN
# 10 Cent Pistol (2015)                               NaN  ...                                        NaN
# 10 Cloverfield Lane (2016)                          NaN  ...                                        NaN
# 10 Items or Less (2006)                             NaN  ...                                        NaN
# 10 Things I Hate About You (1999)                   NaN  ...                                        NaN
# 10 Years (2011)                                     NaN  ...                                        NaN
#
# [20 rows x 9719 columns]

# %%
#Verificando o tamanho da matriz 
movie_rating_matrix.shape
# Out:
# (610, 9719)

# %%
testUser=movie_rating_matrix.iloc[600].dropna()
testUser.head(10).sort_values(ascending=False)
# Out:
# title
# Band of Brothers (2001)     5.0
# 12 Angry Men (1957)         5.0
# Big Hero 6 (2014)           4.5
# Batman Begins (2005)        4.5
# Avengers, The (2012)        4.5
# Blade Runner 2049 (2017)    4.0
# Beautiful Mind, A (2001)    4.0
# Avatar (2009)               4.0
# Armageddon (1998)           4.0
# 2012 (2009)                 4.0
# Name: 601, dtype: float64

# %%
#quantidade de avaliações realizadas pelo usuário
len(testUser)
# Out:
# 101

# %%
#identificando o filme de indice 2
testUser.index[2]
# Out:
# 'Armageddon (1998)'

# %%
#nota atribuída pelo usuário ao filme de indice 2 (Armageddon)
testUser[2]
# Out:
# 4.0

# %%
#encontrando as correlações não nulas entre o filme Armagedon
movie_corr_matrix[testUser.index[2]].dropna().sort_values(ascending=False)
# Out:
# title
# Armageddon (1998)                                                                 1.000000
# Independence Day (a.k.a. ID4) (1996)                                              0.665768
# True Lies (1994)                                                                  0.547632
# Star Wars: Episode I - The Phantom Menace (1999)                                  0.457663
# American Pie (1999)                                                               0.430223
# Men in Black (a.k.a. MIB) (1997)                                                  0.424516
# Indiana Jones and the Temple of Doom (1984)                                       0.420462
# Braveheart (1995)                                                                 0.414973
# Saving Private Ryan (1998)                                                        0.409837
# Mission: Impossible (1996)                                                        0.394391
# Speed (1994)                                                                      0.383551
# Die Hard (1988)                                                                   0.381382
# Aladdin (1992)                                                                    0.372129
# X-Men (2000)                                                                      0.369728
# Truman Show, The (1998)                                                           0.369571
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    0.352328
# Titanic (1997)                                                                    0.330931
# Terminator, The (1984)                                                            0.289789
# Forrest Gump (1994)                                                               0.287674
# Shrek (2001)                                                                      0.281484
# Matrix, The (1999)                                                                0.268305
# Usual Suspects, The (1995)                                                        0.261477
# Mask, The (1994)                                                                  0.253037
# Gladiator (2000)                                                                  0.252315
# Jurassic Park (1993)                                                              0.251622
# Silence of the Lambs, The (1991)                                                  0.249055
# Austin Powers: The Spy Who Shagged Me (1999)                                      0.223152
# Terminator 2: Judgment Day (1991)                                                 0.221962
# Seven (a.k.a. Se7en) (1995)                                                       0.201587
# Sixth Sense, The (1999)                                                           0.188845
# Fight Club (1999)                                                                 0.176218
# Star Wars: Episode VI - Return of the Jedi (1983)                                 0.167125
# Indiana Jones and the Last Crusade (1989)                                         0.162807
# Star Wars: Episode IV - A New Hope (1977)                                         0.151674
# Lord of the Rings: The Return of the King, The (2003)                             0.147588
# There's Something About Mary (1998)                                               0.132714
# Shawshank Redemption, The (1994)                                                  0.124737
# Groundhog Day (1993)                                                              0.118994
# Star Wars: Episode V - The Empire Strikes Back (1980)                             0.116660
# Lord of the Rings: The Two Towers, The (2002)                                     0.114761
# Back to the Future (1985)                                                         0.077618
# Pulp Fiction (1994)                                                               0.073534
# Fifth Element, The (1997)                                                         0.049085
# Toy Story (1995)                                                                  0.046408
# American Beauty (1999)                                                            0.036285
# Alien (1979)                                                                      0.021960
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                        -0.021732
# Memento (2000)                                                                   -0.032096
# Lord of the Rings: The Fellowship of the Ring, The (2001)                        -0.035104
# Godfather, The (1972)                                                            -0.080263
# Fargo (1996)                                                                     -0.199108
# Name: Armageddon (1998), dtype: float64

# %%
similarMoviesCandidates=pd.Series()
for i in range(0,len(testUser.index)):
  print("Adicionando filme similar a " +testUser.index[i]+ "...")
  #recuperando o filme que apresenta correlação
  similar=movie_corr_matrix[testUser.index[i]].dropna()
  similar=similar.map(lambda x: x* testUser[i]) #escala para 5 os filmes com maior similaridade
  similarMoviesCandidates=similarMoviesCandidates.append(similar)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
# Adicionando filme similar a 12 Angry Men (1957)...
# Adicionando filme similar a 2012 (2009)...
# Adicionando filme similar a Armageddon (1998)...
# Adicionando filme similar a Avatar (2009)...
# Adicionando filme similar a Avengers, The (2012)...
# Adicionando filme similar a Band of Brothers (2001)...
# Adicionando filme similar a Batman Begins (2005)...
# Adicionando filme similar a Beautiful Mind, A (2001)...
# Adicionando filme similar a Big Hero 6 (2014)...
# Adicionando filme similar a Blade Runner 2049 (2017)...
# Adicionando filme similar a Bourne Ultimatum, The (2007)...
# Adicionando filme similar a Brave (2012)...
# Adicionando filme similar a Bug's Life, A (1998)...
# Adicionando filme similar a Casablanca (1942)...
# Adicionando filme similar a Casino Royale (2006)...
# Adicionando filme similar a Catch Me If You Can (2002)...
# Adicionando filme similar a City of God (Cidade de Deus) (2002)...
# Adicionando filme similar a Coco (2017)...
# Adicionando filme similar a Contact (1997)...
# Adicionando filme similar a Dark Knight Rises, The (2012)...
# Adicionando filme similar a Departed, The (2006)...
# Adicionando filme similar a District 9 (2009)...
# Adicionando filme similar a Django Unchained (2012)...
# Adicionando filme similar a Dunkirk (2017)...
# Adicionando filme similar a Easy A (2010)...
# Adicionando filme similar a Eternal Sunshine of the Spotless Mind (2004)...
# Adicionando filme similar a Fifth Element, The (1997)...
# Adicionando filme similar a Fight Club (1999)...
# Adicionando filme similar a Finding Nemo (2003)...
# Adicionando filme similar a Gifted (2017)...
# Adicionando filme similar a Girl with the Dragon Tattoo, The (Män som hatar kvinnor) (2009)...
# Adicionando filme similar a Gladiator (2000)...
# Adicionando filme similar a Godfather, The (1972)...
# Adicionando filme similar a Godfather: Part II, The (1974)...
# Adicionando filme similar a Gone Girl (2014)...
# Adicionando filme similar a Good Will Hunting (1997)...
# Adicionando filme similar a Great Escape, The (1963)...
# Adicionando filme similar a Guardians of the Galaxy (2014)...
# Adicionando filme similar a Guardians of the Galaxy 2 (2017)...
# Adicionando filme similar a Harry Potter and the Deathly Hallows: Part 1 (2010)...
# Adicionando filme similar a Help, The (2011)...
# Adicionando filme similar a How to Train Your Dragon (2010)...
# Adicionando filme similar a Howl's Moving Castle (Hauru no ugoku shiro) (2004)...
# Adicionando filme similar a Inception (2010)...
# Adicionando filme similar a Incredibles, The (2004)...
# Adicionando filme similar a Inglourious Basterds (2009)...
# Adicionando filme similar a Inside Out (2015)...
# Adicionando filme similar a Interstellar (2014)...
# Adicionando filme similar a Iron Man (2008)...
# Adicionando filme similar a It's a Wonderful Life (1946)...
# Adicionando filme similar a King's Speech, The (2010)...
# Adicionando filme similar a Life Is Beautiful (La Vita è bella) (1997)...
# Adicionando filme similar a Little Miss Sunshine (2006)...
# Adicionando filme similar a Lord of the Rings: The Fellowship of the Ring, The (2001)...
# Adicionando filme similar a Lord of the Rings: The Return of the King, The (2003)...
# Adicionando filme similar a Lord of the Rings: The Two Towers, The (2002)...
# Adicionando filme similar a Matrix, The (1999)...
# Adicionando filme similar a Memento (2000)...
# Adicionando filme similar a Minority Report (2002)...
# Adicionando filme similar a Monsters, Inc. (2001)...
# Adicionando filme similar a Monty Python and the Holy Grail (1975)...
# Adicionando filme similar a My Neighbor Totoro (Tonari no Totoro) (1988)...
# Adicionando filme similar a North by Northwest (1959)...
# Adicionando filme similar a Ocean's Eleven (2001)...
# Adicionando filme similar a One Flew Over the Cuckoo's Nest (1975)...
# Adicionando filme similar a Pan's Labyrinth (Laberinto del fauno, El) (2006)...
# Adicionando filme similar a Prestige, The (2006)...
# Adicionando filme similar a Princess Bride, The (1987)...
# Adicionando filme similar a Princess Mononoke (Mononoke-hime) (1997)...
# Adicionando filme similar a Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)...
# Adicionando filme similar a Ratatouille (2007)...
# Adicionando filme similar a Rear Window (1954)...
# Adicionando filme similar a Saving Private Ryan (1998)...
# Adicionando filme similar a Schindler's List (1993)...
# Adicionando filme similar a Seven (a.k.a. Se7en) (1995)...
# Adicionando filme similar a Seven Samurai (Shichinin no samurai) (1954)...
# Adicionando filme similar a Shawshank Redemption, The (1994)...
# Adicionando filme similar a She's Out of My League (2010)...
# Adicionando filme similar a Shrek (2001)...
# Adicionando filme similar a Shutter Island (2010)...
# Adicionando filme similar a Sixth Sense, The (1999)...
# Adicionando filme similar a Slumdog Millionaire (2008)...
# Adicionando filme similar a Social Network, The (2010)...
# Adicionando filme similar a Spirited Away (Sen to Chihiro no kamikakushi) (2001)...
# Adicionando filme similar a Steve Jobs: The Man in the Machine (2015)...
# Adicionando filme similar a The Big Sick (2017)...
# Adicionando filme similar a The Godfather Trilogy: 1972-1990 (1992)...
# Adicionando filme similar a The Imitation Game (2014)...
# Adicionando filme similar a Thor: Ragnarok (2017)...
# Adicionando filme similar a Titanic (1997)...
# Adicionando filme similar a To Kill a Mockingbird (1962)...
# Adicionando filme similar a Toy Story (1995)...
# Adicionando filme similar a Toy Story 2 (1999)...
# Adicionando filme similar a Toy Story 3 (2010)...
# Adicionando filme similar a Up (2009)...
# Adicionando filme similar a Usual Suspects, The (1995)...
# Adicionando filme similar a V for Vendetta (2006)...
# Adicionando filme similar a WALL·E (2008)...
# Adicionando filme similar a Whiplash (2013)...
# Adicionando filme similar a Wolf of Wall Street, The (2013)...
# Adicionando filme similar a Zootopia (2016)...

# %%
# ordena os filmes encontrados (serie) em ordem de similaridade
similarMoviesCandidates.sort_values(inplace=True,ascending=False)
print(similarMoviesCandidates.head(15))
# Out:
# 12 Angry Men (1957)                                     5.0
# Saving Private Ryan (1998)                              5.0
# How to Train Your Dragon (2010)                         5.0
# Up (2009)                                               5.0
# Finding Nemo (2003)                                     5.0
# Fight Club (1999)                                       5.0
# Inception (2010)                                        5.0
# Departed, The (2006)                                    5.0
# Godfather, The (1972)                                   5.0
# Incredibles, The (2004)                                 5.0
# Life Is Beautiful (La Vita è bella) (1997)              5.0
# Spirited Away (Sen to Chihiro no kamikakushi) (2001)    5.0
# Shawshank Redemption, The (1994)                        5.0
# Schindler's List (1993)                                 5.0
# Iron Man (2008)                                         5.0
# dtype: float64

# %%
#como os filmes podem aparecer mais de ma vez, soma a similaridade deles
similarMoviesCandidates=similarMoviesCandidates.groupby(similarMoviesCandidates.index).sum()
similarMoviesCandidates.sort_values(inplace=True,ascending=False)
similarMoviesCandidates.head(10)
# Out:
# Matrix, The (1999)                                       86.143677
# Inception (2010)                                         85.205182
# Lord of the Rings: The Return of the King, The (2003)    71.533869
# Monsters, Inc. (2001)                                    69.753100
# Saving Private Ryan (1998)                               69.333854
# Finding Nemo (2003)                                      69.224868
# Fight Club (1999)                                        69.197407
# Silence of the Lambs, The (1991)                         66.731743
# Batman Begins (2005)                                     65.728736
# Shawshank Redemption, The (1994)                         64.043923
# dtype: float64

# %%
#encontra apenas os filmes que o usuário não assistiu
filtra_movies=similarMoviesCandidates[~similarMoviesCandidates.isin(testUser.index)]
filtra_movies.head()
# Out:
# 12 Angry Men (1957)       5.000000
# Aladdin (1992)            1.488515
# Alien (1979)              0.087840
# American Beauty (1999)    0.145139
# American Pie (1999)       1.720891
# dtype: float64

# %%
filme=['12 Angry Men (1957)']
filme in list(testUser.index)
# Out:
# False

# %%
#filmes a serem recomendados
filtra_movies_recomendados=filtra_movies.sort_values(ascending=False)
filtra_movies_recomendados.head(50)
# Out:
# 12 Angry Men (1957)                                          5.000000
# Interstellar (2014)                                          5.000000
# Usual Suspects, The (1995)                                   5.000000
# Lord of the Rings: The Fellowship of the Ring, The (2001)    5.000000
# Lord of the Rings: The Return of the King, The (2003)        5.000000
# Lord of the Rings: The Two Towers, The (2002)                5.000000
# Matrix, The (1999)                                           5.000000
# WALL·E (2008)                                                5.000000
# Memento (2000)                                               5.000000
# Monsters, Inc. (2001)                                        5.000000
# Princess Bride, The (1987)                                   5.000000
# Ratatouille (2007)                                           5.000000
# Rear Window (1954)                                           5.000000
# Saving Private Ryan (1998)                                   5.000000
# Schindler's List (1993)                                      5.000000
# Shawshank Redemption, The (1994)                             5.000000
# Spirited Away (Sen to Chihiro no kamikakushi) (2001)         5.000000
# Iron Man (2008)                                              5.000000
# Life Is Beautiful (La Vita è bella) (1997)                   5.000000
# Incredibles, The (2004)                                      5.000000
# Godfather, The (1972)                                        5.000000
# Departed, The (2006)                                         5.000000
# Inception (2010)                                             5.000000
# Fight Club (1999)                                            5.000000
# Finding Nemo (2003)                                          5.000000
# Up (2009)                                                    5.000000
# How to Train Your Dragon (2010)                              5.000000
# Gladiator (2000)                                             4.500000
# Catch Me If You Can (2002)                                   4.500000
# Avengers, The (2012)                                         4.500000
# Social Network, The (2010)                                   4.500000
# Sixth Sense, The (1999)                                      4.500000
# Shutter Island (2010)                                        4.500000
# Batman Begins (2005)                                         4.500000
# Bug's Life, A (1998)                                         4.500000
# Dark Knight Rises, The (2012)                                4.500000
# Godfather: Part II, The (1974)                               4.500000
# It's a Wonderful Life (1946)                                 4.500000
# District 9 (2009)                                            4.500000
# Prestige, The (2006)                                         4.500000
# North by Northwest (1959)                                    4.500000
# Eternal Sunshine of the Spotless Mind (2004)                 4.500000
# Good Will Hunting (1997)                                     4.500000
# Ocean's Eleven (2001)                                        4.500000
# Wolf of Wall Street, The (2013)                              4.500000
# Lord of the Rings: The Two Towers, The (2002)                4.436507
# Lord of the Rings: The Fellowship of the Ring, The (2001)    4.436507
# Lord of the Rings: The Return of the King, The (2003)        4.249695
# Lord of the Rings: The Fellowship of the Ring, The (2001)    4.249695
# Lord of the Rings: The Return of the King, The (2003)        4.107515
# dtype: float64
