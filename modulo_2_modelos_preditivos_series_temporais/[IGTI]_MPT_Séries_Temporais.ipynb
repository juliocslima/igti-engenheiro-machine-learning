# %% [markdown]
# # **IGTI - MPT**
#
# - Séries temporais
# - [Prof. Matheus Mendonça](https://www.linkedin.com/in/matheusmendonca/)

# %%
# se necessário, descomentar e executar
# !pip install statsmodels --upgrade
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 10.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.7/233.7 KB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3 in /home/jlima/anaconda/envs/udacity-ai-env/lib/python3.8/site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pandas>=0.25 in /home/jlima/anaconda/envs/udacity-ai-env/lib/python3.8/site-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /home/jlima/anaconda/envs/udacity-ai-env/lib/python3.8/site-packages (from statsmodels) (1.19.5)
# Collecting packaging>=21.3
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/jlima/.local/lib/python3.8/site-packages (from packaging>=21.3->statsmodels) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /home/jlima/anaconda/envs/udacity-ai-env/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jlima/.local/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /home/jlima/.local/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# Installing collected packages: patsy, packaging, statsmodels
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 2.21.0 requires grpcio<2.0dev,>=1.38.1, but you have grpcio 1.34.1 which is incompatible.
# Successfully installed packaging-21.3 patsy-0.5.2 statsmodels-0.13.2
# WARNING: You are using pip version 22.0.2; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/jlima/anaconda/envs/udacity-ai-env/bin/python -m pip install --upgrade pip' command.

# %%
# importando as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# ## **Análise de séries temporais**

# %% [markdown]
# ### Decomposição

# %%
# gerando os parâmetros da série sintética
n = 100  # número de amostras
x = np.linspace(0, 2*np.pi, n)
fs = 1/(x[1]-x[0])  # frequência de amostragem da série
f = fs/20  # frequência da série

# %%
# gerador de séries
def generate_series(x, freq, opt='linear_trend+seasonal'):
    if opt == 'linear_trend':
        fx = x 
    elif opt == 'linear_trend+seasonal':
        fx = x  + np.sin(2*np.pi*freq*x)
    elif opt == 'seasonal':
        fx = np.sin(2*np.pi*freq*x)
    else:
        raise ValueError("Unkown opt parameter.")
    return fx

# %%
# método para plot da decomposição
def plot_decomposition(decomposition):
     
    # plot handle
    fig, ax = plt.subplots(figsize=(6, 6), nrows=4)
    
    # original signal
    ax[0].plot(decomposition.observed)
    ax[0].set_title("Series")
    
    # trend component
    ax[1].plot(decomposition.trend)
    ax[1].set_title("Trend")
    
    # seasonal component
    ax[2].plot(decomposition.seasonal)
    ax[2].set_title("Seasonal")
    
    # residue
    ax[3].plot(decomposition.resid)
    ax[3].set_title("Residue")
    
    # plot configuration
    plt.tight_layout()
    plt.show()

# %%
# número de pontos por período
n_points_in_period = int(fs/f)
print(f"Número de pontos por período: {n_points_in_period}")
# Out:
# Número de pontos por período: 20

# %%
# série: tendência linear
series = generate_series(x, f, opt='linear_trend')
decomposition = seasonal_decompose(series,
                                   model='additive',
                                   period=n_points_in_period)
plot_decomposition(decomposition)

# %%
# série: tedência linear + sazonalidade
series = generate_series(x, f, opt='linear_trend+seasonal')
decomposition = seasonal_decompose(series,
                                   model='additive',
                                   period=n_points_in_period)
plot_decomposition(decomposition)

# %%
# série: sazonalidade
series = generate_series(x, f, opt='seasonal')
decomposition = seasonal_decompose(series,
                                   model='additive',
                                   period=n_points_in_period)
plot_decomposition(decomposition)

# %% [markdown]
# ### ACF e PACF

# %%
# leitura dos dados
df = pd.read_csv("https://pycourse.s3.amazonaws.com/monthly_air_passengers.csv",
                 index_col='Month')
df.head()
# Out:
#          #Passengers
# Month
# 1949-01          112
# 1949-02          118
# 1949-03          132
# 1949-04          129
# 1949-05          121

# %%
# plot
df.plot(figsize=(10, 5));

# %%
# decomposição
decomposition = seasonal_decompose(df.values,
                                   model='additive',
                                   period=12)
plot_decomposition(decomposition)

# %%
# verificação de estacionariedade
result = adfuller(df)
print(f'p-value: {result[1]}')
# Out:
# p-value: 0.991880243437641

# %%
# diferenciando a série
df_diff = df.diff().dropna()

# %%
# teste da série diferenciada
result = adfuller(df_diff.dropna())
print(f'p-value: {result[1]}')
# Out:
# p-value: 0.054213290283824704

# %%
# visualização da ACF e PACF
fig, ax = plt.subplots(ncols=2, figsize=(15, 7))
plot_acf(df_diff, ax=ax[0])
plot_pacf(df_diff, ax=ax[1])
plt.show()

# %% [markdown]
# ## **Seleção de parâmetros em modelos ARIMA**

# %%
# se necessário, descomentar e executar
# !pip install pmdarima

# %%
import pmdarima as pm

# %%
# divisão em treino e teste
n, p = len(df), 0.7
train = df[:int(n*p)]
test = df[int(n*p):]

# %%
# treinando o modelo
model = pm.auto_arima(train,
                      seasonal=True,
                      m=12,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)

# relatório
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=647.761, Time=1.25 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=650.796, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=644.203, Time=0.15 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=644.733, Time=0.27 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=645.995, Time=0.04 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=646.172, Time=0.48 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=646.187, Time=0.42 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=644.600, Time=0.28 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=3.40 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=647.442, Time=0.10 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=646.085, Time=0.25 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=645.647, Time=0.28 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=644.346, Time=0.17 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=647.580, Time=0.46 sec
#  ARIMA(1,1,0)(1,1,0)[12] intercept   : AIC=645.940, Time=0.42 sec
#
# Best model:  ARIMA(1,1,0)(1,1,0)[12]
# Total fit time: 8.044 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  100
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -319.101
# Date:                            Tue, 18 Aug 2020   AIC                            644.203
# Time:                                    14:55:53   BIC                            651.601
# Sample:                                         0   HQIC                           647.182
#                                             - 100
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2434      0.097     -2.512      0.012      -0.433      -0.054
# ar.S.L12      -0.2127      0.087     -2.432      0.015      -0.384      -0.041
# sigma2        89.1842     14.080      6.334      0.000      61.587     116.781
# ===================================================================================
# Ljung-Box (Q):                       39.35   Jarque-Bera (JB):                 2.43
# Prob(Q):                              0.50   Prob(JB):                         0.30
# Heteroskedasticity (H):               1.32   Skew:                             0.40
# Prob(H) (two-sided):                  0.46   Kurtosis:                         2.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# predição
forecast = model.predict(n_periods=len(test))

# %%
# plot da predição
plt.figure(figsize=(10, 5))
plt.plot(np.arange(int(n*p)), train.values,'.-', label='Treino')
plt.plot(np.arange(int(n*p), n), test.values,'.-', label='Teste')
plt.plot(np.arange(int(n*p), n), forecast,'.-', label='Predição')
plt.grid()
plt.legend()
plt.show()

# %%
# RMSE
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(test,forecast))
print(f"RMSE do modelo no conjunto de teste: {rmse}")
# Out:
# RMSE do modelo no conjunto de teste: 26.205870291939355

# %%
# plot de diagnóstico
model.plot_diagnostics(figsize=(10, 8));

# %% [markdown]
# ## **Predição utilizando Redes Neurais Recorrentes**

# %%
# utilizando o keras: https://keras.io/
import keras
from sklearn.preprocessing import MinMaxScaler

# %%
# extraindo a série (np.array)
series = df.values

# %%
# normalização (max 1 e min 0)
scaler = MinMaxScaler()
series = scaler.fit_transform(series)

# %%
# divisão em treino e teste
n, p = len(df), 0.7
train = series[:int(n*p)]
test = series[int(n*p):]

# %%
# convertendo a série para uma estrutura x_train, y_train
x_train, y_train = train[:-1], train[1:]
x_test, y_test = test[:-1], test[1:]

# %%
# x_train, y_train: primeiras 5 linhas
print(np.c_[x_train, y_train][:5, :])
# Out:
# [[0.01544402 0.02702703]
#  [0.02702703 0.05405405]
#  [0.05405405 0.04826255]
#  [0.04826255 0.03281853]
#  [0.03281853 0.05984556]]

# %%
# construindo modelo
inputs = keras.layers.Input(shape=(1, 1))
lstm_out = keras.layers.LSTM(4)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1, 1)]            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 4)                 96
# _________________________________________________________________
# dense (Dense)                (None, 1)                 5
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![link text](https://cdn-images-1.medium.com/freeze/max/1000/1*An4tZEyQAYgPAZl396JzWg.png?q=20)

# %%
# fit no modelo
model.fit(x=x_train, y=y_train, batch_size=1, epochs=25)
# Out:
# Epoch 1/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0464
# Epoch 2/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 3/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0169
# Epoch 4/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 5/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 6/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 7/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0116
# Epoch 8/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0104
# Epoch 9/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 10/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0081
# Epoch 11/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0068
# Epoch 12/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0058
# Epoch 13/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0048
# Epoch 14/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 15/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 16/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 17/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 18/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 19/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 20/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 21/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 22/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 23/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 24/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 25/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0020

# %%
# previsão
forecast = model.predict(x_test)

# %%
# valores na escala original
forecast_orig = scaler.inverse_transform(forecast)
y_train_orig = scaler.inverse_transform(y_train)
y_test_orig = scaler.inverse_transform(y_test)

# %%
# plot da predição
n_train, n_test = len(y_train), len(y_test)
plt.figure(figsize=(10, 5))
plt.plot(np.arange(n_train), y_train_orig,'.-', label='Treino')
plt.plot(np.arange(n_train, n_train+n_test), y_test_orig,'.-', label='Teste')
plt.plot(np.arange(n_train, n_train+n_test), forecast_orig,'.-', label='Predição')
plt.grid()
plt.legend()
plt.show()

# %%
# RMSE
rmse = np.sqrt(mean_squared_error(y_test_orig,forecast_orig))
print(f"RMSE do modelo no conjunto de teste: {rmse}")
# Out:
# RMSE do modelo no conjunto de teste: 51.51532290993233

# %%
# adição da sazonalidade como variável exógena
# [s_{t-12}, s_{t-1}] ~ s_t
sz = 12
x_train, y_train = np.c_[train[:-sz], train[sz-1:-1]], train[sz:]
x_test, y_test = np.c_[test[:-sz], test[sz-1:-1]], test

# %%
# contabilização do primeiro ciclo de teste na predição
x_test = np.r_[np.c_[train[-sz:],
                     np.r_[train[-1], test[:sz-1].ravel()]], x_test]

# %%
# construindo modelo
inputs = keras.layers.Input(shape=(2, 1))
lstm_out = keras.layers.LSTM(4)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "functional_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 4)                 96
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit no modelo
model.fit(x=x_train, y=y_train, batch_size=1, epochs=25)
# Out:
# Epoch 1/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0615
# Epoch 2/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 3/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0146
# Epoch 4/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0123
# Epoch 5/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 6/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 7/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 8/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0060
# Epoch 9/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 10/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 11/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 12/25
# 88/88 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 13/25
# 88/88 [==============================] - 0s 1ms/step - loss: 9.0486e-04
# Epoch 14/25
# 88/88 [==============================] - 0s 1ms/step - loss: 8.1014e-04
# Epoch 15/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.8012e-04
# Epoch 16/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.5015e-04
# Epoch 17/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.5148e-04
# Epoch 18/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.2367e-04
# Epoch 19/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.7975e-04
# Epoch 20/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.9797e-04
# Epoch 21/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.4502e-04
# Epoch 22/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.5912e-04
# Epoch 23/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.5709e-04
# Epoch 24/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.6297e-04
# Epoch 25/25
# 88/88 [==============================] - 0s 1ms/step - loss: 7.4719e-04

# %%
# previsão
forecast = model.predict(x_test)

# %%
# valores na escala original
forecast_orig = scaler.inverse_transform(forecast)
y_train_orig = scaler.inverse_transform(y_train)
y_test_orig = scaler.inverse_transform(y_test)

# %%
# plot da predição
n_train, n_test = len(y_train), len(y_test)
plt.figure(figsize=(10, 5))
plt.plot(np.arange(n_train), y_train_orig,'.-', label='Treino')
plt.plot(np.arange(n_train, n_train+n_test), y_test_orig,'.-', label='Teste')
plt.plot(np.arange(n_train, n_train+n_test), forecast_orig,'.-', label='Predição')
plt.grid()
plt.legend()
plt.show()

# %%
# RMSE
rmse = np.sqrt(mean_squared_error(y_test_orig,forecast_orig))
print(f"RMSE do modelo no conjunto de teste: {rmse}")
# Out:
# RMSE do modelo no conjunto de teste: 27.4838135550526
