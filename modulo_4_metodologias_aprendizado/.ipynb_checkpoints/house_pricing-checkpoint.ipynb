# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
tf.__version__
# Out:
# 2022-03-29 18:28:39.331171: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-29 18:28:39.331202: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# '2.8.0'

# %%
df = pd.read_csv('data/kc_house_data.csv', delimiter = ',', encoding='ISO-8859-1')

# %%
df['date'] = pd.to_datetime(df.date, format = '%Y%m%dT%H%M%S')

df = df.sort_values(by='date')

# %%
df.head()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190 2014-05-02  437500.0         3       2.25         1970
# 9596    472000620 2014-05-02  790000.0         3       2.50         2600
# 9587   1024069009 2014-05-02  675000.0         5       2.50         2820
# 20602  7853361370 2014-05-02  555000.0         4       2.50         3310
# 11577  5056500260 2014-05-02  440000.0         4       2.25         2160
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 16768     35100     2.0           0     0  ...      9        1970
# 9596       4750     1.0           0     0  ...      9        1700
# 9587      67518     2.0           0     0  ...      8        2820
# 20602      6500     2.0           0     0  ...      8        3310
# 11577      8119     1.0           0     0  ...      8        1080
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 16768              0      1977             0    98027  47.4635 -121.991
# 9596             900      1951             0    98117  47.6833 -122.400
# 9587               0      1979             0    98029  47.5794 -122.025
# 20602              0      2012             0    98065  47.5150 -121.870
# 11577           1080      1966             0    98006  47.5443 -122.177
#
#        sqft_living15  sqft_lot15
# 16768           2340       35100
# 9596            2380        4750
# 9587            2820       48351
# 20602           2380        5000
# 11577           1850        9000
#
# [5 rows x 21 columns]

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %%
# Verificando o numero de amostras (linhas) e features (colunas) do dataset. 
print('Amostras e Features:', df.shape)
# Out:
# Amostras e Features: (21613, 21)

# %%
# Verificando quais são os tipos das features
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 16768 to 16594
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(15)
# memory usage: 3.6 MB

# %% [markdown]
# # Exploration Data Analysis (EDA)

# %%
plt.figure(figsize=(8,6))

sns.barplot(x='grade',y='price', data=df)
plt.title('House Price per House Class')
plt.xlabel('House Class')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
#looking for outliers. the one in the bottom right we should probably eliminate
sns.scatterplot(x='sqft_living', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
df[df.sqft_living > 10000]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 12777  1225069038 2014-05-05  2280000.0         7        8.0        13540
# 3914   9808700762 2014-06-11  7062500.0         5        4.5        10040
# 7252   6762700020 2014-10-13  7700000.0         6        8.0        12050
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12777    307752     3.0           0     4  ...     12        9410
# 3914      37325     2.0           1     2  ...     11        7680
# 7252      27600     2.5           0     3  ...     13        8570
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12777           4130      1999             0    98053  47.6675 -121.986
# 3914            2360      1940          2001    98004  47.6500 -122.214
# 7252            3480      1910          1987    98102  47.6298 -122.323
#
#        sqft_living15  sqft_lot15
# 12777           4850      217800
# 3914            3930       25449
# 7252            3940        8800
#
# [3 rows x 21 columns]

# %%
df = df[df.sqft_living < 13000]

# %%
sns.scatterplot(data=df, x='sqft_living', y='price')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
numeric_collumns = df.copy().drop(columns=['id', 'date', 'lat', 'long', 'zipcode'])

plt.figure(figsize=(18,16))

sns.heatmap(numeric_collumns.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#newer homes should impact the value
df['year'] = df['date'].apply(lambda date: date.year) 
#Some months see greater home sales and may have a large impact on price
df['month'] = df.date.apply(lambda date: date.month)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.drop('date', axis=1, inplace=True)

# %%
# time to deal with those zipcodes, some zipcodes will 
# positively impact price, some negatively, so lets 
# create dummy variables
zipcode=['zipcode'] 
df = pd.get_dummies(df,columns=zipcode)

# %%
numeric_collumns.hist(bins=20, figsize=(20,20), color='blue')
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'sqft_living'}>],
#        [<AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>,
#         <AxesSubplot:title={'center':'view'}>],
#        [<AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>,
#         <AxesSubplot:title={'center':'sqft_basement'}>],
#        [<AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>,
#         <AxesSubplot:title={'center':'sqft_lot15'}>]], dtype=object)

# %%
features = ['bathrooms', 'bedrooms', 'grade', 'sqft_above', 'sqft_living', 'sqft_living15', 'sqft_basement']

X = df[features]
X.head()
# Out:
#        bathrooms  bedrooms  grade  sqft_above  sqft_living  sqft_living15  \
# 16768       2.25         3      9        1970         1970           2340
# 9596        2.50         3      9        1700         2600           2380
# 9587        2.50         5      8        2820         2820           2820
# 20602       2.50         4      8        3310         3310           2380
# 11577       2.25         4      8        1080         2160           1850
#
#        sqft_basement
# 16768              0
# 9596             900
# 9587               0
# 20602              0
# 11577           1080

# %%
y = df['price']
y = y.values.reshape(-1,1)

# %%
print(X.shape, y.shape)
# Out:
# (21612, 7) (21612, 1)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler 

scaler = MinMaxScaler()

X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# %%
# importar train_test_split do scikitlearn 
from sklearn.model_selection import train_test_split

# Trabalhando base classificacao
# divisão em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size = 0.25,
                                                    random_state = 5762)

# %%
X_train.shape, X_test.shape
# Out:
# ((16209, 7), (5403, 7))

# %%
def build_model(input_shape): 
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape=input_shape))
    model.add(tf.keras.layers.Dense(units=100, activation='relu'))
    model.add(tf.keras.layers.Dense(units=100, activation='relu'))
    model.add(tf.keras.layers.Dense(units=1, activation='linear'))
    return model

# %%
model = build_model((7,))
# Out:
# 2022-03-29 18:29:53.378321: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-29 18:29:53.378371: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-29 18:29:53.378406: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (developer): /proc/driver/nvidia/version does not exist
# 2022-03-29 18:29:53.379615: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               800
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 21,101
# Trainable params: 21,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 406/406 [==============================] - 2s 3ms/step - loss: 0.0011 - val_loss: 8.1186e-04
# Epoch 2/100
# 406/406 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 8.1795e-04
# Epoch 3/100
# 406/406 [==============================] - 1s 3ms/step - loss: 9.3152e-04 - val_loss: 7.8199e-04
# Epoch 4/100
# 406/406 [==============================] - 1s 3ms/step - loss: 9.1603e-04 - val_loss: 8.7820e-04
# Epoch 5/100
# 406/406 [==============================] - 1s 3ms/step - loss: 9.3274e-04 - val_loss: 7.7436e-04
# Epoch 6/100
# 406/406 [==============================] - 1s 3ms/step - loss: 9.3794e-04 - val_loss: 7.7183e-04
# Epoch 7/100
# 406/406 [==============================] - 1s 3ms/step - loss: 9.0303e-04 - val_loss: 8.4802e-04
# Epoch 8/100
# 406/406 [==============================] - 1s 3ms/step - loss: 8
100
# 406/406 [==============================] - 1s 3ms/step - loss: 8.1278e-04 - val_loss: 7.3206e-04
# Epoch 91/100
# 406/406 [==============================] - 1s 4ms/step - loss: 7.9236e-04 - val_loss: 7.8222e-04
# Epoch 92/100
# 406/406 [==============================] - 2s 4ms/step - loss: 8.1430e-04 - val_loss: 7.3362e-04
# Epoch 93/100
# 406/406 [==============================] - 1s 3ms/step - loss: 8.0292e-04 - val_loss: 7.5892e-04
# Epoch 94/100
# 406/406 [==============================] - 1s 3ms/step - loss: 8.0560e-04 - val_loss: 7.3967e-04
# Epoch 95/100
# 406/406 [==============================] - 1s 3ms/step - loss: 8.0913e-04 - val_loss: 7.4427e-04
# Epoch 96/100
# 406/406 [==============================] - 2s 4ms/step - loss: 8.2604e-04 - val_loss: 7.3813e-04
# Epoch 97/100
# 406/406 [==============================] - 1s 3ms/step - loss: 7.9763e-04 - val_loss: 7.3258e-04
# Epoch 98/100
# 406/406 [==============================] - 1s 3ms/step - loss: 7.9456e-04 - val_loss: 7.5890e-04
# Epoch 99/100
# 406/406 [==============================] - 1s 3ms/step - loss: 7.9548e-04 - val_loss: 7.5795e-04
# Epoch 100/100
# 406/406 [==============================] - 2s 4ms/step - loss: 7.9223e-04 - val_loss: 7.4962e-04

# %%
def plot_model_loss(epochs_hist):
    plt.plot(epochs_hist.history['loss'])
    plt.plot(epochs_hist.history['val_loss'])

    plt.title('Model Loss Progression during Training')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend(['Training Loss', 'Validation Loss'])

# %%
plot_model_loss(epochs_hist)

# %%
def plot_result_comparison(y_test, y_predict):
    plt.plot(y_test, y_predict, "^", color='red')
    plt.xlabel('Model predictions')
    plt.ylabel('True values')

# %%
y_predict = model.predict(X_test)

plot_result_comparison(y_test, y_predict)

# %%
y_predict_original = scaler.inverse_transform(y_predict)
y_test_original = scaler.inverse_transform(y_test)

# %%
plot_result_comparison(y_test_original, y_predict_original)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

def calculate_metrics(x_test, y_test_original, y_predict_original):
    n = len(X_test)
    k = X_test.shape[1]
    r2 = r2_score(y_test_original, y_predict_original)
    adj_r2 = 1 - (1 - r2) * (n - 1) / (n - k - 1)

    RMSE = float(format(np.sqrt(mean_squared_error(y_test_original, y_predict_original)),'.3f'))
    MSE = mean_squared_error(y_test_original, y_predict_original)
    MAE = mean_absolute_error(y_test_original, y_predict_original)
    r2 = r2_score(y_test_original, y_predict_original)
    adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

    print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)

# %%
calculate_metrics(X_test, y_test_original, y_predict_original)
# Out:
# RMSE = 236741.627
# MSE = 56046597922.76122
# MAE = 146508.68342818803
# R2 = 0.5984971711882525
# Adjusted R2 = 0.5979762221981353

# %% [markdown]
# ## Adding more features

# %%
features = [
    'bathrooms', 'bedrooms', 'condition', 'grade', 
    'sqft_above', 'sqft_basement', 'sqft_living', 
    'sqft_living15', 'sqft_lot', 'sqft_lot15', 'view', 
    'waterfront', 'yr_built', 'yr_renovated']

X = df[features]
X.head()
# Out:
#        bathrooms  bedrooms  condition  grade  sqft_above  sqft_basement  \
# 16768       2.25         3          4      9        1970              0
# 9596        2.50         3          4      9        1700            900
# 9587        2.50         5          3      8        2820              0
# 20602       2.50         4          3      8        3310              0
# 11577       2.25         4          3      8        1080           1080
#
#        sqft_living  sqft_living15  sqft_lot  sqft_lot15  view  waterfront  \
# 16768         1970           2340     35100       35100     0           0
# 9596          2600           2380      4750        4750     0           0
# 9587          2820           2820     67518       48351     0           0
# 20602         3310           2380      6500        5000     0           0
# 11577         2160           1850      8119        9000     0           0
#
#        yr_built  yr_renovated
# 16768      1977             0
# 9596       1951             0
# 9587       1979             0
# 20602      2012             0
# 11577      1966             0

# %%
y = df['price']

# %%
scaler = MinMaxScaler()

scaled_X = scaler.fit_transform(X)

scaled_y = scaler.fit_transform(y.values.reshape(-1,1))

# %%
# Trabalhando base classificacao
# divisão em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(scaled_X,
                                                    scaled_y,
                                                    test_size = 0.25,
                                                    random_state = 5762)

# %%
# Retraining the model
model = build_model((len(features),))
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
X_train.shape, X_test.shape
# Out:
# ((16209, 14), (5403, 14))

# %%
epochs_hist = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 406/406 [==============================] - 2s 3ms/step - loss: 9.5885e-04 - val_loss: 8.0937e-04
# Epoch 2/100
# 406/406 [==============================] - 1s 3ms/step - loss: 7.2843e-04 - val_loss: 6.5347e-04
# Epoch 3/100
# 406/406 [==============================] - 1s 3ms/step - loss: 6.7124e-04 - val_loss: 8.4919e-04
# Epoch 4/100
# 406/406 [==============================] - 1s 3ms/step - loss: 6.4865e-04 - val_loss: 6.0626e-04
# Epoch 5/100
# 406/406 [==============================] - 1s 3ms/step - loss: 6.3857e-04 - val_loss: 5.8383e-04
# Epoch 6/100
# 406/406 [==============================] - 1s 3ms/step - loss: 6.1744e-04 - val_loss: 6.0244e-04
# Epoch 7/100
# 406/406 [==============================] - 1s 3ms/step - loss: 6.3052e-04 - val_loss: 5.7029e-04
# Epoch 8/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.9730e-04 - val_loss: 5.4900e-04
# Epoch 9/100
# 406/406 [==============================] - 1s 3ms/step - loss: 6.0246e-04 - val_loss: 6.0393e-04
# Epoch 10/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.7248e-04 - val_loss: 5.5763e-04
# Epoch 11/100
# 406/406 [==============================] - 1s 3ms/step - loss: 6.1309e-04 - val_loss: 6.1045e-04
# Epoch 12/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.7326e-04 - val_loss: 6.0534e-04
# Epoch 13/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.8635e-04 - val_loss: 5.6589e-04
# Epoch 14/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.6996e-04 - val_loss: 6.5964e-04
# Epoch 15/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.8066e-04 - val_loss: 5.3310e-04
# Epoch 16/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.6921e-04 - val_loss: 5.7629e-04
# Epoch 17/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.5676e-04 - val_loss: 5.4290e-04
# Epoch 18/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.5462e-04 - val_loss: 7.5822e-04
# Epoch 19/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.5442e-04 - val_loss: 5.7793e-04
# Epoch 20/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.7088e-04 - val_loss: 5.8894e-04
# Epoch 21/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.6136e-04 - val_loss: 6.2703e-04
# Epoch 22/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.3742e-04 - val_loss: 6.0099e-04
# Epoch 23/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.4825e-04 - val_loss: 5.7840e-04
# Epoch 24/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.4891e-04 - val_loss: 6.5802e-04
# Epoch 25/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.3520e-04 - val_loss: 6.5033e-04
# Epoch 26/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.4568e-04 - val_loss: 5.3319e-04
# Epoch 27/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.5590e-04 - val_loss: 5.3643e-04
# Epoch 28/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.3014e-04 - val_loss: 5.4882e-04
# Epoch 29/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5.3732e-04 - val_loss: 5.6378e-04
# Epoch 30/100
# 406/406 [==============================] - 1s 3ms/step - loss: 5
100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.5738e-04 - val_loss: 5.3781e-04
# Epoch 69/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.6267e-04 - val_loss: 5.3908e-04
# Epoch 70/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.9103e-04 - val_loss: 5.8817e-04
# Epoch 71/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.6934e-04 - val_loss: 5.9464e-04
# Epoch 72/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.6028e-04 - val_loss: 5.3234e-04
# Epoch 73/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4928e-04 - val_loss: 4.9613e-04
# Epoch 74/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.6204e-04 - val_loss: 5.2519e-04
# Epoch 75/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.5023e-04 - val_loss: 5.8673e-04
# Epoch 76/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.6048e-04 - val_loss: 5.3453e-04
# Epoch 77/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.5721e-04 - val_loss: 5.3461e-04
# Epoch 78/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4366e-04 - val_loss: 5.5558e-04
# Epoch 79/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.6683e-04 - val_loss: 5.0567e-04
# Epoch 80/100
# 406/406 [==============================] - 2s 4ms/step - loss: 4.5311e-04 - val_loss: 5.2585e-04
# Epoch 81/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4068e-04 - val_loss: 5.1872e-04
# Epoch 82/100
# 406/406 [==============================] - 2s 4ms/step - loss: 4.4042e-04 - val_loss: 5.4537e-04
# Epoch 83/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4545e-04 - val_loss: 5.7782e-04
# Epoch 84/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4169e-04 - val_loss: 5.6257e-04
# Epoch 85/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.3910e-04 - val_loss: 5.3964e-04
# Epoch 86/100
# 406/406 [==============================] - 1s 2ms/step - loss: 4.4517e-04 - val_loss: 5.2013e-04
# Epoch 87/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4398e-04 - val_loss: 5.8830e-04
# Epoch 88/100
# 406/406 [==============================] - 2s 4ms/step - loss: 4.6794e-04 - val_loss: 5.3852e-04
# Epoch 89/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4314e-04 - val_loss: 5.5140e-04
# Epoch 90/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.3699e-04 - val_loss: 5.1481e-04
# Epoch 91/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.2468e-04 - val_loss: 5.4595e-04
# Epoch 92/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4147e-04 - val_loss: 5.8905e-04
# Epoch 93/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.2755e-04 - val_loss: 5.2809e-04
# Epoch 94/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.2072e-04 - val_loss: 5.0998e-04
# Epoch 95/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.2260e-04 - val_loss: 5.5500e-04
# Epoch 96/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.2235e-04 - val_loss: 5.3883e-04
# Epoch 97/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.3738e-04 - val_loss: 5.6897e-04
# Epoch 98/100
# 406/406 [==============================] - 2s 5ms/step - loss: 4.2443e-04 - val_loss: 5.1742e-04
# Epoch 99/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.1527e-04 - val_loss: 5.3986e-04
# Epoch 100/100
# 406/406 [==============================] - 1s 3ms/step - loss: 4.4297e-04 - val_loss: 6.1425e-04

# %%
plot_model_loss(epochs_hist)

# %%
y_predict = model.predict(X_test)

plot_result_comparison(y_test, y_predict)

# %%
y_predict_original = scaler.inverse_transform(y_predict)
y_test_original = scaler.inverse_transform(y_test)

# %%
plot_result_comparison(y_test_original, y_predict_original)
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
calculate_metrics(X_test, y_test_original, y_predict_original)
# Out:
# RMSE = 201476.69
# MSE = 40592856466.98476
# MAE = 133383.1156027323
# R2 = 0.709203639380496
# Adjusted R2 = 0.7084480437886859

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)

# %%
y_predict_original = scaler.inverse_transform(y_pred)
calculate_metrics(X_test, y_test_original, y_predict_original)
# Out:
# RMSE = 219593.164
# MSE = 48221157827.46395
# MAE = 141902.94928347963
# R2 = 0.6545565298542091
# Adjusted R2 = 0.6536589410305191

# %%
reg.score(X_test, y_test)
# Out:
# 0.6545565298542091

# %%
#importar o modelo SVR
from sklearn.svm import SVR

# instanciacao e determinacao dos hiperparâmetros do SVR: tipo de kernel e epsilon
regression = SVR(kernel='rbf', epsilon=1.0)

# treinando o SVR
regression.fit(X_train, y_train)
# Out:
# /home/jlima/anaconda/envs/igti-env/lib/python3.10/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(epsilon=1.0)

# %%
y_pred2 = regression.predict(X_test)

# %%
y_pred2 = y_pred2.reshape(-1, 1)

# %%
y_predict_original = scaler.inverse_transform(y_pred2)
calculate_metrics(X_test, y_test_original, y_predict_original)
# Out:
# RMSE = 3371430.051
# MSE = 11366540591238.545
# MAE = 3351921.347029428
# R2 = -80.42685498012098
# Adjusted R2 = -80.63843181191788

# %%
regression.score(X_test, y_test)
# Out:
# -80.426854980121

# %%
y_predict_original = scaler.inverse_transform(y_predict)
y_test_original = scaler.inverse_transform(y_test)

# %%
plot_result_comparison(y_test_original, y_predict_original)
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
# importar o modelo Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

y_train = y_train.reshape(-1, 1)

# treinando o modelo 
rf = RandomForestRegressor(n_estimators= 10, random_state=42).fit(X_train, y_train);
# Out:
# /tmp/ipykernel_18586/2742016992.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf = RandomForestRegressor(n_estimators= 10, random_state=42).fit(X_train, y_train);

# %%
# aplicando o modelo treinado para a previsão da temperatura 
#em todo o conjunto de teste
y_pred3 = regression.predict(X_test)

# %%
y_pred3 = y_pred3.reshape(-1, 1)

y_predict_original = scaler.inverse_transform(y_pred3)
calculate_metrics(X_test, y_test_original, y_predict_original)
# Out:
# RMSE = 3371430.051
# MSE = 11366540591238.545
# MAE = 3351921.347029428
# R2 = -80.42685498012098
# Adjusted R2 = -80.63843181191788

# %%
def build_model_b(input_shape): 
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(units=512, activation='relu', input_shape=input_shape))
    # When using other datasets and experimenting, I have had a lot of success with 50% dropout  
    model.add(tf.keras.layers.Dropout(.5))                 
    model.add(tf.keras.layers.Dense(units=512, activation='relu'))
    model.add(tf.keras.layers.Dropout(.5))  
    model.add(tf.keras.layers.Dense(units=512, activation='relu'))
    model.add(tf.keras.layers.Dropout(.5))  
    model.add(tf.keras.layers.Dense(512,activation='relu'))
    model.add(tf.keras.layers.Dense(units=1))
    return model

# %%
# Retraining the model
model = build_model_b((len(features),))
model.compile(optimizer='Adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 80)                1200
#
#  dropout_12 (Dropout)        (None, 80)                0
#
#  dense_37 (Dense)            (None, 80)                6480
#
#  dropout_13 (Dropout)        (None, 80)                0
#
#  dense_38 (Dense)            (None, 80)                6480
#
#  dropout_14 (Dropout)        (None, 80)                0
#
#  dense_39 (Dense)            (None, 80)                6480
#
#  dense_40 (Dense)            (None, 1)                 81
#
# =================================================================
# Total params: 20,721
# Trainable params: 20,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

#plan to set epochs deliberately too high and stop early
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose =1, patience=25)

# %%
epochs_hist = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [162], in <cell line: 1>()
# ----> 1 epochs_hist = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
#
# File ~/anaconda/envs/igti-env/lib/python3.10/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/anaconda/envs/igti-env/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#    1148   else:
#    1149     raise
#
# ValueError: in user code:
#
#     File "/home/jlima/anaconda/envs/igti-env/lib/python3.10/site-packages/keras/engine/training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "/home/jlima/anaconda/envs/igti-env/lib/python3.10/site-packages/keras/engine/training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/jlima/anaconda/envs/igti-env/lib/python3.10/site-packages/keras/engine/training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/jlima/anaconda/envs/igti-env/lib/python3.10/site-packages/keras/engine/training.py", line 859, in train_step
#         y_pred = self(x, training=True)
#     File "/home/jlima/anaconda/envs/igti-env/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/jlima/anaconda/envs/igti-env/lib/python3.10/site-packages/keras/engine/input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_8" is incompatible with the layer: expected shape=(None, 14), found shape=(None, 90)

# %%
plot_model_loss(epochs_hist)

# %%
y_predict = model.predict(X_test)

plot_result_comparison(y_test, y_predict)

# %%
y_predict_original = scaler.inverse_transform(y_predict)
y_test_original = scaler.inverse_transform(y_test)

# %%
plot_result_comparison(y_test_original, y_predict_original)
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
calculate_metrics(X_test, y_test_original, y_predict_original)
# Out:
# RMSE = 264848.435
# MSE = 70144693268.93623
# MAE = 152015.42698695412
# R2 = 0.4767724455172966
# Adjusted R2 = 0.47541316072183215

# %%
reg.score(X_test, y_test)
# Out:
# 0.6501850944084808

# %%
X = df.drop('price', axis=1)
y= df.price

# %%
# Scale the data for the model
scaler = MinMaxScaler()

scaled_X = scaler.fit_transform(X)

scaled_y = scaler.fit_transform(y.values.reshape(-1,1))

# %%
# Trabalhando base classificacao
# divisão em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(scaled_X,
                                                    scaled_y,
                                                    test_size = 0.25,
                                                    random_state = 5762)

# %%
X_train.shape
# Out:
# (16209, 90)

# %%
# Retraining the model
model = build_model_b((90,))
model.compile(optimizer='adam', loss='mse')

# %%
epochs_hist = model.fit(X_train, y_train, epochs=600, batch_size=32, validation_split=0.2, callbacks = [early_stop])
# Out:
# Epoch 1/600
# 406/406 [==============================] - 2s 3ms/step - loss: 0.0054 - val_loss: 0.0023
# Epoch 2/600
# 406/406 [==============================] - 1s 3ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 3/600
# 406/406 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 4/600
# 406/406 [==============================] - 1s 3ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 5/600
# 406/406 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 6/600
# 406/406 [==============================] - 1s 3ms/step - loss: 9.7471e-04 - val_loss: 0.0014
# Epoch 7/600
# 406/406 [==============================] - 1s 3ms/step - loss: 8.8265e-04 - val_loss: 0.0011
# Epoch 8/600
# 406/406 [==============================] - 1s 3ms/step - loss: 8.7718e-04 - val_loss: 0.0013
# Epoch 9/600
# 406/406 [==============================] - 1s 3ms/step - loss: 7.9108e-04 - val_loss: 0.0012
# Epoch 10/600
# 406/406 [==============================] - 1s 3ms/step - loss: 7.5388e-04 - val_loss: 0.0017
# Epoch 11/600
# 406/406 [==============================] - 1s 3ms/step - loss: 7.5832e-04 - val_loss: 0.0013
# Epoch 12/600
# 406/406 [==============================] - 1s 3ms/step - loss: 6.8251e-04 - val_loss: 0.0016
# Epoch 13/600
# 406/406 [==============================] - 1s 3ms/step - loss: 6.8531e-04 - val_loss: 0.0014
# Epoch 14/600
# 406/406 [==============================] - 1s 3ms/step - loss: 6.7666e-04 - val_loss: 0.0015
# Epoch 15/600
# 406/406 [==============================] - 1s 3ms/step - loss: 5
600
# 406/406 [==============================] - 1s 2ms/step - loss: 4.2585e-04 - val_loss: 0.0010
# Epoch 50/600
# 406/406 [==============================] - 1s 2ms/step - loss: 4.5408e-04 - val_loss: 9.5281e-04
# Epoch 51/600
# 406/406 [==============================] - 1s 2ms/step - loss: 4.1304e-04 - val_loss: 9.8051e-04
# Epoch 52/600
# 406/406 [==============================] - 1s 2ms/step - loss: 4.6904e-04 - val_loss: 9.6418e-04
# Epoch 53/600
# 406/406 [==============================] - 1s 2ms/step - loss: 4.7659e-04 - val_loss: 0.0010
# Epoch 54/600
# 406/406 [==============================] - 1s 2ms/step - loss: 4.5536e-04 - val_loss: 9.6579e-04
# Epoch 55/600
# 406/406 [==============================] - 1s 3ms/step - loss: 4.2707e-04 - val_loss: 9.3008e-04
# Epoch 56/600
# 406/406 [==============================] - 2s 4ms/step - loss: 4.3588e-04 - val_loss: 9.2884e-04
# Epoch 57/600
# 406/406 [==============================] - 2s 5ms/step - loss: 4.7223e-04 - val_loss: 8.8347e-04
# Epoch 58/600
# 406/406 [==============================] - 2s 5ms/step - loss: 4.2293e-04 - val_loss: 9.8551e-04
# Epoch 59/600
# 406/406 [==============================] - 3s 7ms/step - loss: 4.3398e-04 - val_loss: 9.9898e-04
# Epoch 60/600
# 406/406 [==============================] - 1s 3ms/step - loss: 4.1844e-04 - val_loss: 0.0011
# Epoch 61/600
# 406/406 [==============================] - 1s 3ms/step - loss: 4.3659e-04 - val_loss: 9.7527e-04
# Epoch 62/600
# 406/406 [==============================] - 2s 4ms/step - loss: 4.3464e-04 - val_loss: 0.0010
# Epoch 63/600
# 406/406 [==============================] - 2s 6ms/step - loss: 4.3086e-04 - val_loss: 9.5797e-04
# Epoch 63: early stopping

# %%
plot_model_loss(epochs_hist)

# %%
y_predict = model.predict(X_test)

plot_result_comparison(y_test, y_predict)

# %%
y_predict_original = scaler.inverse_transform(y_predict)
y_test_original = scaler.inverse_transform(y_test)

# %%
plot_result_comparison(y_test_original, y_predict_original)
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
calculate_metrics(X_test, y_test_original, y_predict_original)
# Out:
# RMSE = 197005.233
# MSE = 38811062018.71102
# MAE = 102097.20174555802
# R2 = 0.7219679379794738
# Adjusted R2 = 0.7172573043985537

# %%
epochs_hist = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.5967e-04 - val_loss: 4.8409e-04
# Epoch 2/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.6528e-04 - val_loss: 4.5449e-04
# Epoch 3/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3730e-04 - val_loss: 5.2685e-04
# Epoch 4/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.5985e-04 - val_loss: 4.6366e-04
# Epoch 5/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2475e-04 - val_loss: 5.2285e-04
# Epoch 6/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.6240e-04 - val_loss: 5.2427e-04
# Epoch 7/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.6450e-04 - val_loss: 4.9550e-04
# Epoch 8/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.4550e-04 - val_loss: 5.4803e-04
# Epoch 9/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.7484e-04 - val_loss: 5.0743e-04
# Epoch 10/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.5733e-04 - val_loss: 4.8606e-04
# Epoch 11/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.4244e-04 - val_loss: 5.2740e-04
# Epoch 12/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.4098e-04 - val_loss: 5.5332e-04
# Epoch 13/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.5649e-04 - val_loss: 4.8320e-04
# Epoch 14/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3299e-04 - val_loss: 5.2919e-04
# Epoch 15/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.7616e-04 - val_loss: 4.8108e-04
# Epoch 16/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3440e-04 - val_loss: 4.6494e-04
# Epoch 17/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3148e-04 - val_loss: 4.6756e-04
# Epoch 18/200
# 406/406 [==============================] - 1s 2ms/step - loss: 3
200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.4216e-04 - val_loss: 4.3297e-04
# Epoch 162/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.5748e-04 - val_loss: 4.2928e-04
# Epoch 163/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.1332e-04 - val_loss: 4.5226e-04
# Epoch 164/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.0937e-04 - val_loss: 4.8110e-04
# Epoch 165/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.1814e-04 - val_loss: 4.7167e-04
# Epoch 166/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2136e-04 - val_loss: 3.8783e-04
# Epoch 167/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3707e-04 - val_loss: 4.9902e-04
# Epoch 168/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.5851e-04 - val_loss: 4.4660e-04
# Epoch 169/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2249e-04 - val_loss: 4.6983e-04
# Epoch 170/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.4871e-04 - val_loss: 4.5194e-04
# Epoch 171/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.0888e-04 - val_loss: 4.9390e-04
# Epoch 172/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2739e-04 - val_loss: 4.1366e-04
# Epoch 173/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.1472e-04 - val_loss: 4.8989e-04
# Epoch 174/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2971e-04 - val_loss: 4.2226e-04
# Epoch 175/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.9711e-04 - val_loss: 4.7966e-04
# Epoch 176/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2563e-04 - val_loss: 5.0290e-04
# Epoch 177/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2171e-04 - val_loss: 4.8635e-04
# Epoch 178/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2094e-04 - val_loss: 4.6834e-04
# Epoch 179/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.4347e-04 - val_loss: 5.4668e-04
# Epoch 180/200
# 406/406 [==============================] - 1s 2ms/step - loss: 3.2984e-04 - val_loss: 4.5788e-04
# Epoch 181/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.1148e-04 - val_loss: 4.5805e-04
# Epoch 182/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2695e-04 - val_loss: 5.0604e-04
# Epoch 183/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3305e-04 - val_loss: 4.6920e-04
# Epoch 184/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3626e-04 - val_loss: 4.9457e-04
# Epoch 185/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2753e-04 - val_loss: 4.8828e-04
# Epoch 186/200
# 406/406 [==============================] - 1s 2ms/step - loss: 3.9178e-04 - val_loss: 4.4510e-04
# Epoch 187/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.5564e-04 - val_loss: 3.7246e-04
# Epoch 188/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3440e-04 - val_loss: 3.9929e-04
# Epoch 189/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.0784e-04 - val_loss: 4.2452e-04
# Epoch 190/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.0707e-04 - val_loss: 4.5430e-04
# Epoch 191/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3044e-04 - val_loss: 4.8542e-04
# Epoch 192/200
# 406/406 [==============================] - 1s 2ms/step - loss: 3.9987e-04 - val_loss: 3.9699e-04
# Epoch 193/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3296e-04 - val_loss: 3.6596e-04
# Epoch 194/200
# 406/406 [==============================] - 1s 2ms/step - loss: 3.5030e-04 - val_loss: 4.0650e-04
# Epoch 195/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3596e-04 - val_loss: 4.0571e-04
# Epoch 196/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.6590e-04 - val_loss: 4.4024e-04
# Epoch 197/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.5804e-04 - val_loss: 4.1246e-04
# Epoch 198/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.2934e-04 - val_loss: 4.4467e-04
# Epoch 199/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.1987e-04 - val_loss: 3.9512e-04
# Epoch 200/200
# 406/406 [==============================] - 1s 3ms/step - loss: 3.3102e-04 - val_loss: 5.3120e-04

# %%
plot_model_loss(epochs_hist)

# %%
y_predict = model.predict(X_test)

plot_result_comparison(y_test, y_predict)

# %%
y_predict_original = scaler.inverse_transform(y_predict)
y_test_original = scaler.inverse_transform(y_test)

# %%
plot_result_comparison(y_test_original, y_predict_original)
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
calculate_metrics(X_test, y_test_original, y_predict_original)
# Out:
# RMSE = 202230.836
# MSE = 40897311197.11179
# MAE = 102521.41178222747
# R2 = 0.7070226071694137
# Adjusted R2 = 0.702058758269799
